# %% [markdown]
# # 載入套件

# %%
import os
import re
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from IPython.display import display

# %% [markdown]
# # 儲存資料集的物件

# %%
class SegmentDataSet():
    def __init__(self):
        self.types = ['F', 'U', 'SP', 'LP']
        self.file_paths = {typ: f'D:\ebg408\data\segment_data\{typ}_data' for typ in self.types}
        self.file_name_list = {typ: os.listdir(file_path) for typ, file_path in self.file_paths.items()}
        self.F_data = {file_name: pd.read_csv(os.path.join(self.file_paths['F'], file_name)) for file_name in self.file_name_list['F']}
        self.U_data = {file_name: pd.read_csv(os.path.join(self.file_paths['U'], file_name)) for file_name in self.file_name_list['U']}
        self.SP_data = {file_name: pd.read_csv(os.path.join(self.file_paths['SP'], file_name)) for file_name in self.file_name_list['SP']}
        self.LP_data = {file_name: pd.read_csv(os.path.join(self.file_paths['LP'], file_name)) for file_name in self.file_name_list['LP']}
        self.all_data = {**self.F_data, **self.U_data, **self.SP_data, **self.LP_data}
    
    def to_csv(self, file_path):
        '''輸出成csv檔'''
        for file_name, df in self.all_data.items():
            df.to_csv(f'{file_path}{file_name}', index=False)

# %% [markdown]
# ## 建立一個資料集物件

# %%
data = SegmentDataSet()

# %% [markdown]
# ## 偷看一下資料長什麼樣子

# %%
data.all_data[data.file_name_list['F'][1]]
# Out:
#     type  no.  group.no  player.no  Trials  StockPrice  Dprice   Cash  Stock  \
# 0   flat  101        22         43      20          74      -2  10324      6
# 1   flat  101        22         43      21          72      -2  10398      5
# 2   flat  101        22         43      22          70      -2  10470      4
# 3   flat  101        22         43      23          75       5  10400      5
# 4   flat  101        22         43      24          75       0  10400      5
# 5   flat  101        22         43      25          75       0  10400      5
# 6   flat  101        22         43      26          75       0  10400      5
# 7   flat  101        22         43      27          73      -2  10475      4
# 8   flat  101        22         43      28          73       0  10475      4
# 9   flat  101        22         43      29          73       0  10475      4
# 10  flat  101        22         43      30          78       5  10402      5
# ...

# %% [markdown]
# # 儲存Upper/Lower Bound的物件

# %%
class UpperLowerBounds():
    def __init__(self, dataset, typ):
        self.upper_lower_bounds = self.get_result(dataset, typ)
        self.typ = typ

    def upper_bound(self, df):
        # filters
        maxprice = df.loc[:,'StockPrice'] == max(df.loc[:,'StockPrice'])
        action = df.loc[:,'Decision'] != 'buy'
        lag_action = df.loc[:,'lag_Decision'] == 'buy'
        # 筆記：
        # 也可用df.loc[:,'lag_Decision'].shift(1)來取lag值

        # 篩選出符合條件的資料點
        # 回傳(回合數, 價格)
        matched_df = df[maxprice & action & lag_action]
        upper_bounds = [(row['Trials'], row['StockPrice']) for _, row in matched_df.iterrows()]

        # return results
        return upper_bounds
    
    def lower_bound(self, df):
        # filters
        minprice = df.loc[:, 'StockPrice'] == min(df.loc[:,'StockPrice'])
        action = df.loc[:, 'Decision'] != 'sell'
        lag_action = df.loc[:, 'lag_Decision'] == 'sell'
        stock = df.loc[:, 'Stock'] != 0

        # 篩選出符合條件的資料點
        # 回傳(回合數, 價格)
        matched_df = df[minprice & action & lag_action & stock]
        lower_bounds = [(row['Trials'], row['StockPrice']) for _, row in matched_df.iterrows()]

        # return results
        return lower_bounds

    def get_result(self, dataset, typ):
        upper_lower_bounds = dict()

        # 先依照behavior pattern類型決定任務
        if typ == 'F':
            dataset = dataset.F_data
        elif typ == 'U':
            dataset = dataset.U_data
        elif typ == 'SP':
            dataset = dataset.SP_data
        elif typ == 'LP':
            dataset = dataset.LP_data
        elif typ == 'all':
            dataset = dataset.all_data
        else:
            print('Error argument')
        for name, df in dataset.items():
            upper_lower_bounds[name] = {'upper_bounds': self.upper_bound(df), 'lower_bounds': self.lower_bound(df)}

        return upper_lower_bounds

    def plot_counts(self):
        '''畫出每個人分別擁有的upper/lower bound數量分配'''
        # get all value
        UB = [value['upper_bounds'] for key, value in self.upper_lower_bounds.items()]
        LB = [value['lower_bounds'] for key, value in self.upper_lower_bounds.items()]

        # count them
        UB_counts = Counter([len(UBs) for UBs in UB])
        LB_counts = Counter([len(LBs) for LBs in LB])

        # plot
        N = max(UB_counts.keys() | LB_counts.keys())

        ind = np.arange(N)  # the x locations for the groups

        df = pd.DataFrame({'Upper Bound': UB_counts, 'Lower Bound': LB_counts})
        df.sort_index(inplace=True)
        ax = df.plot.bar(rot=0)

        ax.set_ylabel('Counts')
        ax.set_title(f'"{self.typ}" Upper/Lower Bound Counts')
        ax.set_xticks(ind)

        plt.show()
        
        # print df
        display(df.round().transpose())
        
        # print some statistics
        print(f'{round((UB_counts[0]/sum(UB_counts.values()))*100, 1)}% have no Upper Bound')
        print(f'{round((LB_counts[0]/sum(LB_counts.values()))*100, 1)}% have no Lower Bound')

    
    def plot_values(self, typ):
        '''
        畫出upper/lower bound的值的分配，typ有"trial"、"price"兩種可以選
        "trial"：一個價格可能對應多個回合數，皆會算入分配中
        "price"：upper/lower bound分別最多只可能有一種price，故不會重複算入分配中
        註：所以以上兩種的資料點加總起來可能不會一樣
        '''
        if typ == 'trial':
            UB = [[ub[0] for ub in value['upper_bounds']] for _, value in self.upper_lower_bounds.items() if value['upper_bounds']]
            LB = [[lb[0] for lb in value['lower_bounds']] for _, value in self.upper_lower_bounds.items() if value['lower_bounds']]
            # flatten nested lists
            UB = list(itertools.chain(*UB))
            LB = list(itertools.chain(*LB))

        if typ == 'price':
            UB = [value['upper_bounds'][0][1] for _, value in self.upper_lower_bounds.items() if value['upper_bounds']]
            LB = [value['lower_bounds'][0][1] for _, value in self.upper_lower_bounds.items() if value['lower_bounds']]

        # plot
        bins = np.linspace(min([*UB, *LB]), max([*UB, *LB]), 100)
        plt.hist(UB, bins=bins, alpha=0.5, label='Upper Bound')
        plt.hist(LB, bins=bins, alpha=0.5, label='Lower Bound')
        plt.legend(loc='upper right')
        plt.title(f'"{self.typ}" Upper/Lower Bound Values')
        plt.show()

        # show some statistics
        stats = pd.DataFrame({'Upper Bound': statistics(UB), 'Lower Bound': statistics(LB)}).transpose()
        display(stats.round(1))

    def naive_comparison(self):
        '''計算lower_bound的price-upper_bound的price'''
        # calculate diffs (lower_bound - upper_bound)
        diffs = []
        nones = 0
        for _, value in self.upper_lower_bounds.items():
            if value['lower_bounds'] and value['upper_bounds']:
                diff = value['lower_bounds'][0][1] - value['upper_bounds'][0][1]
                diffs.append(diff)
            else:
                nones += 1
        
        # plot diffs
        plt.hist(diffs, bins=np.linspace(min(diffs), max(diffs), 100))
        plt.title(f'"{self.typ}" diffs (lower_bound - upper_bound)')
        plt.show()

        # show some statistics
        stats = pd.DataFrame({'diff': statistics(diffs)}).transpose()
        display(stats)
        print(f'There are {nones} Nones.')
    
    def count_none(self):
        counts = {'both': 0, 'only_U': 0, 'only_L': 0, 'none': 0}
        for _, value in self.upper_lower_bounds.items():
            if value['lower_bounds'] and value['upper_bounds']:
                counts['both'] += 1
            elif value['upper_bounds'] and not value['lower_bounds']:
                counts['only_U'] += 1
            elif value['lower_bounds'] and not value['upper_bounds']:
                counts['only_L'] += 1
            else:
                counts['none'] += 1
        display(pd.DataFrame({'count': counts}).transpose())

# %% [markdown]
# ### 輸出一些描述統計的函式

# %%
def statistics(dataset: list) -> dict:
    stat = dict()
    stat['Mean'] = np.mean(dataset)
    stat['std'] = np.std(dataset)
    stat['Max'] = max(dataset)
    stat['Min'] = min(dataset)
    stat['Median'] = np.median(dataset)

    return stat

# %% [markdown]
# ## 建立一個儲存Upper/Lower Bound的物件

# %%
ULB = UpperLowerBounds(data, typ='all')

# %%
ULB.upper_lower_bounds
# Out:
# {'F_100_43_1_17.csv': {'upper_bounds': [(2, 100)], 'lower_bounds': []},
#  'F_101_43_20_31.csv': {'upper_bounds': [(30, 78)],
#   'lower_bounds': [(22, 70)]},
#  'F_102_43_36_101.csv': {'upper_bounds': [], 'lower_bounds': []},
#  'F_103_44_3_13.csv': {'upper_bounds': [],
#   'lower_bounds': [(4, 93), (12, 93)]},
#  'F_104_44_17_101.csv': {'upper_bounds': [(64, 123)], 'lower_bounds': []},
#  'F_105_45_1_17.csv': {'upper_bounds': [(2, 103),
#    (4, 103),
#    (6, 103),
#    (8, 103),
#    (10, 103)],
#   'lower_bounds': [(14, 95), (16, 95)]},
#  'F_106_45_17_28.csv': {'upper_bounds': [], 'lower_bounds': [(21, 95)]},
#  'F_107_45_50_69.csv': {'upper_bounds': [(62, 112)], 'lower_bounds': []},
#  'F_108_45_78_89.csv': {'upper_bounds': [(79, 105)],
#   'lower_bounds': [(84, 90)]},
#  'F_109_46_1_13.csv': {'upper_bounds': [], 'lower_bounds': [(12, 97)]},
#  'F_10_13_70_101.csv': {'upper_bounds': [(71, 108)],
#   'lower_bounds': [(99, 71)]},
#  'F_110_46_16_26.csv': {'upper_bounds': [],
# ...

# %% [markdown]
# # Upper/Lower Bound的數量

# %%
ULB.plot_counts()
# Out:
#                  0      1     2     3    4    5    6    7
# Upper Bound  332.0  549.0  47.0  15.0  3.0  1.0  NaN  NaN
# Lower Bound  405.0  440.0  78.0  17.0  4.0  1.0  1.0  1.0
# 35.1% have no Upper Bound
# 42.8% have no Lower Bound

# %% [markdown]
# # Upper/Lower Bound的值

# %%
ULB.plot_values(typ='price')
# Out:
#               Mean   std    Max   Min  Median
# Upper Bound  121.7  52.8  625.0  69.0   109.0
# Lower Bound   96.2  23.4  314.0  59.0    94.0

# %%
ULB.plot_values(typ='trial')
# Out:
#              Mean   std    Max  Min  Median
# Upper Bound  48.0  26.8   99.0  2.0    52.0
# Lower Bound  43.7  30.3  101.0  2.0    33.0

# %% [markdown]
# # Upper/Lower Bound的差值
# (自己的lower bound的值 - upper bound的值)

# %%
ULB.naive_comparison()
# Out:
#       Max      Mean  Median    Min        std
# diff -4.0 -23.50646   -16.0 -364.0  31.855404
# There are 560 Nones.

# %% [markdown]
# # 有無Upper/Lower Bound組合的數量

# %%
ULB.count_none()
# Out:
#        both  none  only_L  only_U
# count   387   177     155     228

# %% [markdown]
# # 將upper/lower bound標記於以behavior pattern區分的section資料

# %%
def update_ULB(ULB_data, dataset):
    '''輸出標記過upper/lower bound的原始資料'''
    # 針對所有資料標記
    for file_name, ULBs in ULB_data.upper_lower_bounds.items():
        df = dataset.all_data[file_name]

        # 取得upper/lower bound的回合數資訊
        UBs = [upper_bound[0] for upper_bound in ULBs['upper_bounds']]
        LBs = [lower_bound[0] for lower_bound in ULBs['lower_bounds']]
        bounds = []  # 儲存Bound的資料(upper/lower/none)

        # 掃過該df的每一個資料點
        for _, row in df.iterrows():
            if row['Trials'] in UBs:
                bounds.append('upper')
            elif row['Trials'] in LBs:
                bounds.append('lower')
            else:
                bounds.append('None')

        # 將Bound資料加入原df
        df['Bound'] = bounds
        dataset.all_data[file_name] = df

# %%
update_ULB(ULB, data)

# %% [markdown]
# ### 檢查一下

# %%
ULB.upper_lower_bounds[data.file_name_list['F'][0]]
# Out:
# {'upper_bounds': [(2, 100)], 'lower_bounds': []}

# %%
data.all_data[data.file_name_list['F'][0]]
# Out:
#     type  no.  group.no  player.no  Trials  StockPrice  Dprice   Cash  Stock  \
# 0   flat  100        22         43       1         100     NaN  10000     10
# 1   flat  100        22         43       2         100     0.0   9900     11
# 2   flat  100        22         43       3          97    -3.0   9900     11
# 3   flat  100        22         43       4          93    -4.0   9997     10
# 4   flat  100        22         43       5          96     3.0   9997     10
# 5   flat  100        22         43       6          94    -2.0  10093      9
# 6   flat  100        22         43       7          97     3.0   9999     10
# 7   flat  100        22         43       8          95    -2.0   9999     10
# 8   flat  100        22         43       9          95     0.0   9999     10
# 9   flat  100        22         43      10          95     0.0   9999     10
# 10  flat  100        22         43      11          95     0.0   9999     10
# ...

# %% [markdown]
# ### 輸出成csv檔

# %%
data.to_csv('D:\\ebg408\\data\\segment_data_ULB\\')

# %% [markdown]
# # 將upper/lower bound標記於100回合的原始資料

# %% [markdown]
# ### 先載入進來再說吧

# %%
class OriginalDataSet():
    def __init__(self):
        self.file_path = 'D:\ebg408\data\original_data'
        self.file_name_list = os.listdir(file_paths)
        self.id_filename = {file_name[:3]: file_name for file_name in self.file_name_list}
        self.all_data = {file_name[:3]: pd.read_csv(os.path.join(self.file_path, file_name)) for file_name in self.file_name_list}
        self.bounds = {file_name[:3]: ['NA']*101 for file_name in self.file_name_list}
        self.bounds_typ = {file_name[:3]: ['NA']*101 for file_name in self.file_name_list}

    def to_csv(self, file_path):
        '''輸出成csv檔'''
        for file_name, df in self.all_data.items():
            df.to_csv(f'{file_path}{self.id_filename[file_name]}', index=False)

# %%
ori_data = OriginalDataSet()

# %% [markdown]
# ### 偷看一下資料長什麼樣子

# %%
ori_data.all_data['043']
# Out:
#      Trials  MarketCondition  StockPrice  p1Cash  p1Stock  p1TotalAsset  \
# 0         1                1         100   10000       10         11000
# 1         2                1         100    9900       11         11000
# 2         3                1          97    9900       11         10967
# 3         4                1          93    9997       10         10927
# 4         5                1          96    9997       10         10957
# ..      ...              ...         ...     ...      ...           ...
# 96       97                3          74   10807        0         10807
# 97       98                3          74   10807        0         10807
# 98       99                3          74   10807        0         10807
# 99      100                3          74   10807        0         10807
# 100     101                3          74   10807        0         10807
#
#     p1Decision p1ChechHistory
# 0          buy             no
# 1     no trade             no
# ...

# %%
print(ori_data.bounds['043'])
print(ori_data.bounds_typ['043'])
print(len(ori_data.bounds['043']))
# Out:
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
# ...

# %%
def original_update_ULB(ULB_data, dataset):
    '''輸出每一個人的bound資料'''
    # 先建立每個人bounds的資料
    for file_name, ULBs in ULB_data.upper_lower_bounds.items():
        # 先以RegEx取得UPB資料中的受試者編號
        player_id_regex = r'\D*_\d*_(\d*)_\d*_\d*\.csv'
        player_id = re.findall(player_id_regex, file_name)[0].zfill(3)
        
        typ_regex = r'(\D*)_\d*_\d*_\d*_\d*\.csv'
        typ = re.findall(type_regex, file_name)[0]

        # 取得upper/lower bound的回合數資訊
        if ULBs['upper_bounds']:
            for upper_bound in ULBs['upper_bounds']:
                trial = upper_bound[0]
                
                # 標記bound的類型
                dataset.bounds[player_id][trial-1] = 'upper'

                # 標記bound是屬於哪個類型的區間
                # 若兩種區間都有一樣的bound，應都標示出來，並以逗號隔開
                bound_type = dataset.bounds_typ[player_id][trial-1]
                if bound_type == 'NA':
                    dataset.bounds_typ[player_id][trial-1] = typ
                else:
                    dataset.bounds_typ[player_id][trial-1] = bound_type + ',' +typ

        if ULBs['lower_bounds']:
            for lower_bound in ULBs['lower_bounds']:
                trial = lower_bound[0]

                # 標記bound的類型
                dataset.bounds[player_id][trial-1] = 'lower'

                # 標記bound是屬於哪個類型的區間
                # 若兩種區間都有一樣的bound，應都標示出來，並以逗號隔開
                bound_type = dataset.bounds_typ[player_id][trial-1]
                if bound_type == 'NA':
                    dataset.bounds_typ[player_id][trial-1] = typ
                else:
                    dataset.bounds_typ[player_id][trial-1] = bound_type + ',' +typ

    # 再結合進原始資料
    for player_id, _ in dataset.all_data.items():
        dataset.all_data[player_id]['Bound'] = dataset.bounds[player_id]
        dataset.all_data[player_id]['Bound_Type'] = dataset.bounds_typ[player_id]

# %%
original_update_ULB(ULB, ori_data)

# %% [markdown]
# ### 檢查一下

# %%
ori_data.all_data['043']
# Out:
#      Trials  MarketCondition  StockPrice  p1Cash  p1Stock  p1TotalAsset  \
# 0         1                1         100   10000       10         11000
# 1         2                1         100    9900       11         11000
# 2         3                1          97    9900       11         10967
# 3         4                1          93    9997       10         10927
# 4         5                1          96    9997       10         10957
# ..      ...              ...         ...     ...      ...           ...
# 96       97                3          74   10807        0         10807
# 97       98                3          74   10807        0         10807
# 98       99                3          74   10807        0         10807
# 99      100                3          74   10807        0         10807
# 100     101                3          74   10807        0         10807
#
#     p1Decision p1ChechHistory  Bound Bound_Type
# 0          buy             no     NA         NA
# ...

# %% [markdown]
# ### 輸出成csv檔

# %%
ori_data.to_csv('D:\\ebg408\\data\\original_data_ULB\\')

# %% [markdown]
# ### 有趣現象
# 60號受試者第6回合就有bound重疊的情形

# %%
ori_data.all_data['060'].iloc[5]
# Out:
# Trials                 6
# MarketCondition        1
# StockPrice            94
# p2Cash             10298
# p2Stock                7
# p2TotalAsset       10956
# p2Decision           buy
# p2ChechHistory       yes
# Bound              lower
# Bound_Type          F,SP
# Name: 5, dtype: object

# %% [markdown]
# # TODO
# 分成四種來看

# %%
F_ULB = UpperLowerBounds(data, typ='F')
U_ULB = UpperLowerBounds(data, typ='U')
SP_ULB = UpperLowerBounds(data, typ='SP')
LP_ULB = UpperLowerBounds(data, typ='LP')

# %%
F_ULB.plot_counts()
U_ULB.plot_counts()
SP_ULB.plot_counts()
LP_ULB.plot_counts()
# Out:
#                  0      1     2     3    4    5    6    7
# Upper Bound  194.0  290.0  32.0  11.0  2.0  1.0  NaN  NaN
# Lower Bound  225.0  250.0  44.0   6.0  2.0  1.0  1.0  1.0
# 36.6% have no Upper Bound
# 42.5% have no Lower Bound
#                 0     1    2
# Upper Bound  64.0  27.0  NaN
# Lower Bound  67.0  21.0  3.0
# 70.3% have no Upper Bound
# 73.6% have no Lower Bound
#                 0      1     2    3    4
# Upper Bound  67.0  125.0  10.0  3.0  NaN
# Lower Bound  55.0  115.0  26.0  7.0  2.0
# 32.7% have no Upper Bound
# 26.8% have no Lower Bound
#                 0      1    2    3    4
# Upper Bound   7.0  107.0  5.0  1.0  1.0
# Lower Bound  58.0   54.0  5.0  4.0  NaN
# 5.8% have no Upper Bound
# 47.9% have no Lower Bound

# %%
F_ULB.plot_values()
U_ULB.plot_values()
SP_ULB.plot_values()
LP_ULB.plot_values()
# Out:
#               Mean   std    Max   Min  Median
# Upper Bound  116.3  41.7  625.0  75.0   107.0
# Lower Bound   96.2  25.9  314.0  61.0    94.0
#               Mean   std    Max   Min  Median
# Upper Bound  125.4  99.8  625.0  69.0   105.0
# Lower Bound   93.0   9.8  109.0  69.0    95.0
#               Mean   std    Max   Min  Median
# Upper Bound  123.8  49.3  454.0  85.0   110.0
# Lower Bound   95.1  20.5  275.0  59.0    94.0
#               Mean   std    Max   Min  Median
# Upper Bound  134.3  65.8  525.0  91.0   116.0
# Lower Bound  100.5  19.7  184.0  70.0    94.0

# %%
F_ULB.naive_comparison()
U_ULB.naive_comparison()
SP_ULB.naive_comparison()
LP_ULB.naive_comparison()
# Out:
#       Max       Mean  Median    Min        std
# diff -4.0 -20.420091   -14.0 -265.0  24.148641
# There are 311 Nones.
#       Max  Mean  Median   Min       std
# diff -4.0  -7.0    -6.0 -10.0  2.529822
# There are 86 Nones.
#       Max       Mean  Median    Min        std
# diff -5.0 -24.273585   -18.0 -179.0  22.017374
# There are 99 Nones.
#       Max       Mean  Median    Min        std
# diff -5.0 -35.385965   -22.0 -364.0  59.534968
# There are 64 Nones.
